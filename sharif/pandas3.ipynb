# %%
# !pip install -U pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 126.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
data = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
animals = ["Cat", "Dog", "Tiger"]
p_animals = pd.Series(animals)
p_animals
# Out:
# 0      Cat
# 1      Dog
# 2    Tiger
# dtype: object

# %%
type(p_animals)
# Out:
# pandas.core.series.Series

# %%
p_animals[2]
# Out:
# 'Tiger'

# %%
numbers = [2.0, 20, 1.5]
p_numbers = pd.Series(numbers)
p_numbers
# Out:
# 0     2.0
# 1    20.0
# 2     1.5
# dtype: float64

# %%
test = ['cat', "red", None]
p = pd.Series(test)
p
# Out:
# 0     cat
# 1     red
# 2    None
# dtype: object

# %%
test2 = [2.0, 20, None]
p2 = pd.Series(test2)
p2
# Out:
# 0     2.0
# 1    20.0
# 2     NaN
# dtype: float64

# %%
animal = {
    'first': 'Cat',
    'second': 'Dog',
    'third': 'Tiger'
}

p_animal = pd.Series(animal)
p_animal
# Out:
# first       Cat
# second      Dog
# third     Tiger
# dtype: object

# %%
print(p_animal['first'])
# Out:
# Cat

# %%
print(p_animal.iloc[2])
# Out:
# Tiger

# %%
type(p_animals)
# Out:
# pandas.core.series.Series

# %%
p_animal.index
# Out:
# Index(['first', 'second', 'third'], dtype='object')

# %%
p_animal.values
# Out:
# array(['Cat', 'Dog', 'Tiger'], dtype=object)

# %%
p_animals = pd.Series(['cat', 'tiger','dog'], index=['n1','n2','n3'])
p_animals
# Out:
# n1      cat
# n2    tiger
# n3      dog
# dtype: object

# %%
p_animals['n1']
# Out:
# 'cat'

# %%
p_animals.loc['n2']
# Out:
# 'tiger'

# %%
for item in p_animals:
  print('Salam ' + str(item))
# Out:
# Salam cat
# Salam tiger
# Salam dog

# %%
'Salam ' + p_animals
# Out:
# n1      Salam cat
# n2    Salam tiger
# n3      Salam dog
# dtype: object

# %%
import numpy as np
import pandas as pd

numbers = [2.0, 4 , 40.1]
p2 = pd.Series(numbers)
np.sum(p2)
# Out:
# np.float64(46.1)

# %%
animal = {
    'first': 'Cat',
    'second': 'Dog',
    'third': 'Tiger'
}
p_animal = pd.Series(animal)
number = {
    'first': 1,
    'second': 2.90,
    'third': 0.04
}
p_number = pd.Series(numbers)
number2 = {
    'first': 10000,
    'second': 200000.90,
    'third': 0.000004
}
p_number2 = pd.Series(number2)

df = pd.DataFrame([p_animal, p_number, p_number2], ['n1', 'n2', 'n3'])
df
# Out:
#       first    second     third    0    1     2
# n1      Cat       Dog     Tiger  NaN  NaN   NaN
# n2      NaN       NaN       NaN  2.0  4.0  40.1
# n3  10000.0  200000.9  0.000004  NaN  NaN   NaN

# %%
df['first']
# Out:
# n1        Cat
# n2        NaN
# n3    10000.0
# Name: first, dtype: object

# %%
df.T
# Out:
#            n1    n2        n3
# first     Cat   NaN   10000.0
# second    Dog   NaN  200000.9
# third   Tiger   NaN  0.000004
# 0         NaN   2.0       NaN
# 1         NaN   4.0       NaN
# 2         NaN  40.1       NaN

# %%
df['first']
# Out:
# n1        Cat
# n2        NaN
# n3    10000.0
# Name: first, dtype: object

# %%
df[['first']]
# Out:
#       first
# n1      Cat
# n2      NaN
# n3  10000.0

# %%
df2 = df

# %%
df2.drop('n1', inplace=True)

# %%
df
# Out:
#       first    second     third    0    1     2
# n2      NaN       NaN       NaN  2.0  4.0  40.1
# n3  10000.0  200000.9  0.000004  NaN  NaN   NaN

# %%
df2
# Out:
#       first    second     third    0    1     2
# n2      NaN       NaN       NaN  2.0  4.0  40.1
# n3  10000.0  200000.9  0.000004  NaN  NaN   NaN

# %%
animal = {
    'first': 'Cat',
    'second': 'Dog',
    'third': 'Tiger'
}
p_animal = pd.Series(animal)
number = {
    'first': 1,
    'second': 2.90,
    'third': 0.04
}
p_number = pd.Series(numbers)
number2 = {
    'first': 10000,
    'second': 200000.90,
    'third': 0.000004
}
p_number2 = pd.Series(number2)

df = pd.DataFrame([p_animal, p_number, p_number2], ['n1', 'n2', 'n3'])
df
# Out:
#       first    second     third    0    1     2
# n1      Cat       Dog     Tiger  NaN  NaN   NaN
# n2      NaN       NaN       NaN  2.0  4.0  40.1
# n3  10000.0  200000.9  0.000004  NaN  NaN   NaN

# %%
df3 = df[['first', 0]]

# %%
df3.drop('n1', inplace=True )
# Out:
# /tmp/ipython-input-4037086403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop('n1', inplace=True )

# %%
t = df['second']
type(t)
# Out:
# pandas.core.series.Series

# %%
s = df.T['n1']
type(s)
s += '!@'
s
# Out:
# first       Cat!@
# second      Dog!@
# third     Tiger!@
# 0             NaN
# 1             NaN
# 2             NaN
# Name: n1, dtype: object

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
len(data[data['latitude'] > 39.50].index)
# Out:
# 598

# %%
len(data)
# Out:
# 20640

# %%
df_test =data[data['households'] > 4]

# %%
len(df_test)
# Out:
# 20628

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df = data[(data['total_rooms'] > 880) & (data['population'] > 1000)]

# %%
data['TEST']= data['total_rooms'] * data['population']
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#          TEST
# 0    283360.0
# 1  17044699.0
# 2    727632.0
# ...

# %%
data['TEST']
# Out:
# 0          283360.0
# 1        17044699.0
# 2          727632.0
# 3          710892.0
# 4          919255.0
#             ...
# 20635     1406925.0
# 20636      248132.0
# 20637     2269778.0
# 20638     1378260.0
# 20639     3862795.0
# Name: TEST, Length: 20640, dtype: float64

# %%
data['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
data['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
data.groupby('ocean_proximity')['TEST'].min()
# Out:
# ocean_proximity
# <1H OCEAN         54.0
# INLAND            12.0
# ISLAND        302152.0
# NEAR BAY         104.0
# NEAR OCEAN       128.0
# Name: TEST, dtype: float64

# %%
data.groupby('ocean_proximity')['TEST'].aggregate(lambda x:x.sum() /len(x) )
# Out:
# ocean_proximity
# <1H OCEAN     6.148779e+06
# INLAND        6.237210e+06
# ISLAND        1.208396e+06
# NEAR BAY      4.548910e+06
# NEAR OCEAN    5.190425e+06
# Name: TEST, dtype: float64

# %%
data.groupby('ocean_proximity')['TEST'].aggregate(lambda x:x.max()  - x.min())
# Out:
# ocean_proximity
# <1H OCEAN     932022828.0
# INLAND        641112588.0
# ISLAND          2292748.0
# NEAR BAY      152212088.0
# NEAR OCEAN    391403437.0
# Name: TEST, dtype: float64

# %%
import pandas as pd

# %%
data = pd.read_csv('https://corgis-edu.github.io/corgis/datasets/csv/airlines/airlines.csv')

# %%
data.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# ...

# %%
data.columns
# Out:
# Index(['Airport.Code', 'Airport.Name', 'Time.Label', 'Time.Month',
#        'Time.Month Name', 'Time.Year', 'Statistics.# of Delays.Carrier',
#        'Statistics.# of Delays.Late Aircraft',
#        'Statistics.# of Delays.National Aviation System',
#        'Statistics.# of Delays.Security', 'Statistics.# of Delays.Weather',
#        'Statistics.Carriers.Names', 'Statistics.Carriers.Total',
#        'Statistics.Flights.Cancelled', 'Statistics.Flights.Delayed',
#        'Statistics.Flights.Diverted', 'Statistics.Flights.On Time',
#        'Statistics.Flights.Total', 'Statistics.Minutes Delayed.Carrier',
#        'Statistics.Minutes Delayed.Late Aircraft',
#        'Statistics.Minutes Delayed.National Aviation System',
#        'Statistics.Minutes Delayed.Security',
#        'Statistics.Minutes Delayed.Total',
#        'Statistics.Minutes Delayed.Weather'],
#       dtype='object')

# %%
data['Statistics.# of Delays.Weather'].mean()
# Out:
# np.float64(78.21687840290382)

# %%
data['Statistics.# of Delays.Weather'].value_counts()
# Out:
# Statistics.# of Delays.Weather
# 36     59
# 41     56
# 26     56
# 37     55
# 27     55
#        ..
# 304     1
# 635     1
# 281     1
# 229     1
# 250     1
# Name: count, Length: 346, dtype: int64

# %%
from scipy import stats

# %%
stats.trim_mean(data['Statistics.# of Delays.Weather'], 0.1)
# Out:
# np.float64(65.33361678004535)

# %%
data['Statistics.# of Delays.Weather'].mean()
# Out:
# np.float64(78.21687840290382)

# %%
data['Statistics.# of Delays.Weather'].median()
# Out:
# 58.0

# %%
data['Statistics.# of Delays.Weather'].mode() # more used on non numerical columns
# Out:
# 0    36
# Name: Statistics.# of Delays.Weather, dtype: int64

# %%
data['Statistics.# of Delays.Weather'].var()
# Out:
# 5652.29195921185

# %%
data['Statistics.# of Delays.Weather'].std()
# Out:
# 75.18172623192321

# %%
data['Statistics.# of Delays.Weather'].hist(bins=100)
# Out:
# <Axes: >

# %%
data['Statistics.# of Delays.Weather'][data['Statistics.# of Delays.Weather']< 100].hist(bins=100)
# Out:
# <Axes: >

# %%
data['Statistics.# of Delays.Weather'].skew()
# Out:
# np.float64(3.4078557966893905)

# %%
data.dtypes
# Out:
# Airport.Code                                           object
# Airport.Name                                           object
# Time.Label                                             object
# Time.Month                                              int64
# Time.Month Name                                        object
# Time.Year                                               int64
# Statistics.# of Delays.Carrier                          int64
# Statistics.# of Delays.Late Aircraft                    int64
# Statistics.# of Delays.National Aviation System         int64
# Statistics.# of Delays.Security                         int64
# Statistics.# of Delays.Weather                          int64
# Statistics.Carriers.Names                              object
# Statistics.Carriers.Total                               int64
# Statistics.Flights.Cancelled                            int64
# Statistics.Flights.Delayed                              int64
# ...

# %%
numeric_df = data.select_dtypes(include=['number'])
print(numeric_df)
# Out:
#       Time.Month  Time.Year  Statistics.# of Delays.Carrier  \
# 0              6       2003                            1009
# 1              6       2003                             374
# 2              6       2003                             296
# 3              6       2003                             300
# 4              6       2003                             283
# ...          ...        ...                             ...
# 4403           1       2016                             280
# 4404           1       2016                             357
# 4405           1       2016                             560
# 4406           1       2016                             338
# 4407           1       2016                             410
#
#       Statistics.# of Delays.Late Aircraft  \
# 0                                     1275
# 1                                      495
# 2                                      477
# 3                                      472
# ...

# %%
numeric_df.corr()
# Out:
#                                                     Time.Month  Time.Year  \
# Time.Month                                            1.000000  -0.075977
# Time.Year                                            -0.075977   1.000000
# Statistics.# of Delays.Carrier                       -0.008749  -0.067204
# Statistics.# of Delays.Late Aircraft                 -0.021178   0.000373
# Statistics.# of Delays.National Aviation System      -0.010177  -0.195279
# Statistics.# of Delays.Security                       0.044398  -0.315334
# Statistics.# of Delays.Weather                       -0.063141  -0.191346
# Statistics.Carriers.Total                             0.009466  -0.483083
# Statistics.Flights.Cancelled                         -0.132985  -0.046951
# Statistics.Flights.Delayed                           -0.016750  -0.127542
# Statistics.Flights.Diverted                          -0.009689  -0.005181
# Statistics.Flights.On Time                            0.024357  -0.052625
# ...

# %%
import math

def sample_size_calculator(population_size, confidence_level, margin_of_error):
  z_score = {
      0.90: 1.645,
      0.95: 1.96,
      0.99: 2.576
  }

  z = z_score[confidence_level]
  p = 0.5
  q = 1 - p

  sample_size = ((z**2) * p * q * population_size) / ((z**2 * q) +(margin_of_error**2) * (population_size - 1))
  return math.ceil (sample_size)

# Example Usage
population_size = 100000000
confidence_level = 0.99
margin_of_error = 0.05

sample_size = sample_size_calculator(population_size, confidence_level, margin_of_error)
print(f"The required sample size is: {sample_size}")
# Out:
# The required sample size is: 664
